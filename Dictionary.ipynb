# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanridho16/Python_Docs/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Dictionary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# To find the type of dictionary, use type() function as follows:

empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %% [markdown]
# ## Accessing values in a Dictionary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1) Using square bracket notation
#
# ![image.png](data:image/png;base64,...)

# %%
# shows how to get values associated with the key

person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

print(person['first_name'])
print(person['last_name'])
# Out:
# John
# Doe

# %% [markdown]
# ### 2) Using the get() method
#
# ![image.png](data:image/png;base64,...)

# %%
# To avoid this error, you can use the get() method of the dictionary

person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

age = person.get('age')
ssn = person.get('ssn')
print(age)
print(ssn)
# Out:
# 21
# None

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# The following example returns the '000-00-0000' string 
# if the ssn key doesn’t exist in the person dictionary:

person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

ssn = person.get('ssn', '00-00-0000')
print(ssn)
# Out:
# 00-00-0000

# %% [markdown]
# ## Adding new key-value pairs
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Modifying values in a key-value pair
#
# ![image.png](data:image/png;base64,...)

# %%
# Following example modifies the values associated with age of the person dictionary

person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

person['age'] = 26

print(person)
# Out:
# {'first_name': 'John', 'last_name': 'Doe', 'age': 26, 'favorite_colors': ['blue', 'green'], 'active': True}

# %% [markdown]
# ## Removing key-value pairs
# ![image.png](data:image/png;base64,...)

# %%
person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

del person['active']

print(person)
# Out:
# {'first_name': 'John', 'last_name': 'Doe', 'age': '21', 'favorite_colors': ['blue', 'green']}

# %% [markdown]
# ## Looping through a dictionary
#
# ![image.png](data:image/png;base64,...)

# %%
for orang in person:
  print(orang)
# Out:
# first_name
# last_name
# age
# favorite_colors

# %% [markdown]
# ### 1) Looping all key-value pairs in a dictionary
#
# ![image.png](data:image/png;base64,...)

# %%
person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

print(person.items())
# Out:
# dict_items([('first_name', 'John'), ('last_name', 'Doe'), ('age', '21'), ('favorite_colors', ['blue', 'green']), ('active', True)])

# %%
'''
To iterate over all key-value pairs in a dictionary, 
you use a for loop with two variable key and value to unpack each tuple of the list:
'''

person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

for key, value in person.items():
  print(f"{key}, {value}")
# Out:
# first_name, John
# last_name, Doe
# age, 21
# favorite_colors, ['blue', 'green']
# active, True

# %%
for keydanvalue in person.items():
  print(keydanvalue)
# Out:
# ('first_name', 'John')
# ('last_name', 'Doe')
# ('age', '21')
# ('favorite_colors', ['blue', 'green'])
# ('active', True)

# %% [markdown]
# ### 2) Looping through all the keys in a dictionary
#
# ![image.png](data:image/png;base64,...)

# %%
person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

for key in person.keys():
  print(key)
# Out:
# first_name
# last_name
# age
# favorite_colors
# active

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# if we don't use a key() function

person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

for key in person:
  print(key)
# Out:
# first_name
# last_name
# age
# favorite_colors
# active

# %% [markdown]
# ### 3) Looping through all the values in a dictionary
#
# ![image.png](data:image/png;base64,...)

# %%
person = {
    'first_name' : 'John',
    'last_name' : 'Doe',
    'age' : '21',
    'favorite_colors' : ['blue', 'green'],
    'active' : True
}

for value in person.values():
  print(value)
# Out:
# John
# Doe
# 21
# ['blue', 'green']
# True

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dictionary Comprehension
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python dictionary comprehension examples

# %% [markdown]
# ### 1) Using Python dictionary comprehension to transform a dictionary

# %%
# stock symbol and price
stocks = {
    'AAPL': 121,
    'AMZN': 3380,
    'MSFT': 219,
    'BIIB': 280,
    'QDEL': 266,
    'LVGO': 144
}

# increase price of each stock by 2%
new_stocks = {}
for symbol, price in stocks.items():
  new_stocks[symbol] = price*1.02

print(new_stocks)
# Out:
# {'AAPL': 123.42, 'AMZN': 3447.6, 'MSFT': 223.38, 'BIIB': 285.6, 'QDEL': 271.32, 'LVGO': 146.88}

# %%
# Use dictionary comprehenssion for same result

stocks = {
    'AAPL': 121,
    'AMZN': 3380,
    'MSFT': 219,
    'BIIB': 280,
    'QDEL': 266,
    'LVGO': 144
}

new_stocks = {symbol: price*1.02 for (symbol, price) in stocks.items()}

print(new_stocks)

# this dictionary comprehension have some result with for loop counterpart
# Out:
# {'AAPL': 123.42, 'AMZN': 3447.6, 'MSFT': 223.38, 'BIIB': 285.6, 'QDEL': 271.32, 'LVGO': 146.88}

# %% [markdown]
# ### 2) Using python dictionary comprehension to filter a dictionary

# %%
# select stocks whose prices are greater than 200
# -----------------------------------------------

stocks = {
    'AAPL': 121,
    'AMZN': 3380,
    'MSFT': 219,
    'BIIB': 280,
    'QDEL': 266,
    'LVGO': 144
}

selected_stocks = {}
for symbol, price in stocks.items():
  if price > 200:
    selected_stocks[symbol] = price

print(selected_stocks)
# Out:
# {'AMZN': 3380, 'MSFT': 219, 'BIIB': 280, 'QDEL': 266}

# %%
# Uses the dictionary comprehension with an if clause to get the same result:
stocks = {
    'AAPL': 121,
    'AMZN': 3380,
    'MSFT': 219,
    'BIIB': 280,
    'QDEL': 266,
    'LVGO': 144
}

selected_stocks = {s: p for (s, p) in stocks.items() if p > 200}

print(selected_stocks)
# Out:
# {'AMZN': 3380, 'MSFT': 219, 'BIIB': 280, 'QDEL': 266}

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)
