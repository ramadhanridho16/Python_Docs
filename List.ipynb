# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanridho16/Python_Docs/blob/main/List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python List

# %% [markdown]
# ## What is List
#
# ![image.png](data:image/png;base64,...)

# %%
numbers = [1, 3, 2, 7, 9, 4]

# %%
print(numbers)
# Out:
# [1, 3, 2, 7, 9, 4]

# %%
colors = ['red', 'green', 'blue']
print(colors)
# Out:
# ['red', 'green', 'blue']

# %%
coordinates = [[0, 0], [100, 100], [200, 200]]
print(coordinates)
# Out:
# [[0, 0], [100, 100], [200, 200]]

# %% [markdown]
# ### **Penggambaran**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Accesing elements in a list
#
# ![image.png](data:image/png;base64,...)

# %%
numbers = [1, 3, 2, 7, 9, 4]

print(numbers[0])
# Out:
# 1

# %%
numbers = [1, 3, 2, 7, 9, 4]

print(numbers[1])
# Out:
# 3

# %%
# The negative index allows you to access elements starting from the end of the list

numbers = [1, 3, 2, 7, 9, 4]
print(numbers[-1])
print(numbers[-2])
# Out:
# 4
# 9

# %% [markdown]
# ## Modifying, adding, and removing elements

# %% [markdown]
# ### 1) Modifying elements in a list
#
# ![image.png](data:image/png;base64,...)

# %%
numbers = [1, 3, 2, 7, 9, 4]
numbers[0] = 10

print(numbers)
# Out:
# [10, 3, 2, 7, 9, 4]

# %%
# multiply element in list

numbers = [1, 3, 2, 7, 9, 4]
numbers[1] = numbers[1]*10

print(numbers)
# Out:
# [1, 30, 2, 7, 9, 4]

# %%
# divides the third element by 2:

numbers = [1, 3, 2, 7, 9, 4]
numbers[2] /= 2

print(numbers)
# Out:
# [1, 3, 1.0, 7, 9, 4]

# %% [markdown]
# ### 2) Adding elememts to the list

# %%
numbers = [1, 3, 2, 7, 9, 4]
numbers.append(100)

print(numbers)
# Out:
# [1, 3, 2, 7, 9, 4, 100]

# %%
# insert() method adss a new element at any position in the list

numbers = [1, 3, 2, 7, 9, 4]
numbers.insert(2, 100)

print(numbers)
# Out:
# [1, 3, 100, 2, 7, 9, 4]

# %% [markdown]
# ### 3) Removing elements from a list

# %%
# del statement

numbers = [1, 3, 2, 7, 9, 4]
del numbers[0]

print(numbers)
# Out:
# [3, 2, 7, 9, 4]

# %%
# The pop() method removes the last element from a list and returns that element:

numbers = [1, 3, 2, 7, 9, 4]
last = numbers.pop()

print(last)
print(numbers)
# Out:
# 4
# [1, 3, 2, 7, 9]

# %%
'''
Typically, you use the pop() method when you want to remove an element from a list 
and still want to access the value of that element.

To pop an element by its position, you use the pop() with the element’s index. For example:
'''

numbers = [1, 3, 2, 7, 9, 4]

second = numbers.pop(1)

print(second)
print(numbers)
# Out:
# 3
# [1, 2, 7, 9, 4]

# %%
# To remove an element by value, you use the remove() method.

numbers = [1, 3, 2, 7, 9, 4]

numbers.remove(9)
print(numbers)
# Out:
# [1, 3, 2, 7, 4]

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Tuples

# %% [markdown]
# ## Introduction to Python tuples
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Defining a tuple
#
# ![image.png](data:image/png;base64,...)

# %%
# Once you define a tuple, you can access an individual element by its index, just. For example:

rgb = ('red', 'green', 'blue')

print(rgb[0])
print(rgb[1])
print(rgb[2])
# Out:
# red
# green
# blue

# %%
'''
Since a tuple is immutable, you cannot change its elements. 
The following example attempts to change the first element of the rgb tuple to 'yellow':
'''

rgb = ('red', 'green', 'blue')
# rgb[0] = 'yellow'

# %% [markdown]
# ## Defining a tuple that has one element
#
# ![image.png](data:image/png;base64,...)

# %%
numbers = (3,)
print(type(numbers))
print(numbers)
# Out:
# <class 'tuple'>
# (3,)

# %%
'''
If you exclude the trailing comma, the type of the numbers will be int , which stands for integer. 
And its value is 3. Python won’t create a tuple that includes the number 3:
'''

numbers = (3)
print(type(numbers))
# Out:
# <class 'int'>

# %% [markdown]
# ## Assigning a tuple
#
# ![image.png](data:image/png;base64,...)

# %%
colors = ('red', 'green', 'blue')
print(colors)

colors = ('Cyan', 'Magenta', 'Yellow', 'black')
print(colors)
# Out:
# ('red', 'green', 'blue')
# ('Cyan', 'Magenta', 'Yellow', 'black')

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Sort List

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python List sort() method examples

# %% [markdown]
# ### 1) Using the Python List sort() method to sort a list of strings

# %%
# If a list contains strings, the sort() method sorts the string elements alphabetically.

guests = ['James', 'Mary', 'John', 'Patricia', 'Robert', 'Jennifer']
guests.sort()

print(guests)
# Out:
# ['James', 'Jennifer', 'John', 'Mary', 'Patricia', 'Robert']

# %%
''' And the following example uses the sort() method with the reverse=True 
argument to sort the elements in the guests list in the reverse alphabetical order:
'''

guests = ['James', 'Mary', 'John', 'Patricia', 'Robert', 'Jennifer']
guests.sort(reverse=True)

print(guests)
# Out:
# ['Robert', 'Patricia', 'Mary', 'John', 'Jennifer', 'James']

# %% [markdown]
# ### 2) Using the Python List sort() method to sort a list of numbers

# %%
scores = [5, 7, 4, 6, 9, 8]
scores.sort()

print(scores)
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
# largest to smallest

scores = [5, 7, 4, 6, 9, 8]
scores.sort(reverse=True)

print(scores)
# Out:
# [9, 8, 7, 6, 5, 4]

# %% [markdown]
# ### 3) Using the Python List sort() method to sort a list of tuples
#
# ![image.png](data:image/png;base64,...)

# %%
# Note that you just pass the function name without the parentheses to the sort() method:

companies = [('Google', 2019, 134.81),
             ('Apple', 2019, 260.2),
             ('Facebook', 2019, 70.7)]

# define a sort key
def sort_key(company):
  return company[2]

# sort the companies by revenue
companies.sort(key=sort_key, reverse=True)

# show the sorted companies
print(companies)
# Out:
# [('Apple', 2019, 260.2), ('Google', 2019, 134.81), ('Facebook', 2019, 70.7)]

# %% [markdown]
# #### Using Lambda Expression
#
# ![image.png](data:image/png;base64,...)

# %%
# The following example uses the lambda expression to sort the companies by revenue from low to high:

companies = [('Google', 2019, 134.81),
             ('Apple', 2019, 260.2),
             ('Facebook', 2019, 70.7)]

# sort companies by revenue
companies.sort(key=lambda company:company[2])

# show the sorted companies
print(companies)
# Out:
# [('Facebook', 2019, 70.7), ('Google', 2019, 134.81), ('Apple', 2019, 260.2)]

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Sorted

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python sorted() function examples

# %%
help(sorted)    # the utility of the sorted function can use the help function
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %% [markdown]
# ### 1) Using Python sorted() function to sort a list of strings

# %%
guests = ['James', 'Mary', 'John', 'Patricia', 'Robert', 'Jennifer']
sorted_guests = sorted(guests)

print(guests)
print(sorted_guests)


"""
As you can see clearly the output, the original list doesn’t change. 
The sorted() method returns a new sorted list from the original list.
"""
# Out:
# ['James', 'Mary', 'John', 'Patricia', 'Robert', 'Jennifer']
# ['James', 'Jennifer', 'John', 'Mary', 'Patricia', 'Robert']

# %%
# reverse alphabetical order

guests = ['James', 'Mary', 'John', 'Patricia', 'Robert', 'Jennifer']
sorted_guests = sorted(guests, reverse=True)

print(sorted_guests)
# Out:
# ['Robert', 'Patricia', 'Mary', 'John', 'Jennifer', 'James']

# %% [markdown]
# ### 2) Using Python sorted() function to sort a list of numbers

# %%
scores = [5, 7, 4, 6, 9, 8]
sorted_scores = sorted(scores)

print(sorted_scores)
# Out:
# [4, 5, 6, 7, 8, 9]

# %%
# reverse argument from largest to smallest

scores = [5, 7, 4, 6, 9, 8]
sorted_scores = sorted(scores, reverse=True)

print(sorted_scores)
# Out:
# [9, 8, 7, 6, 5, 4]

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python List Slice

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python List Slice Examples

# %% [markdown]
# ### 1) Basic Python list slice example

# %%
# example

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
sub_colors = colors[1:4]

print(sub_colors)

'''
This example doesn’t use the step, 
so the slice gets all values within the range without skipping any elements.
'''
# Out:
# ['orange', 'yellow', 'green']
# '\nThis example doesn’t use the step, \nso the slice gets all values within the range without skipping any elements.\n'

# %% [markdown]
# ### 2) Using Python List slice to get the n-first elements from a list
#
# ![image.png](data:image/png;base64,...)

# %%
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
sub_colors = colors[:4]

print(sub_colors)

# it's equivalent to the color[0:4]
# Out:
# ['red', 'orange', 'yellow', 'green']

# %% [markdown]
# ### 3) Using Python List slice to get the n-last elements from a list

# %%
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
sub_colors = colors[-3:]

print(sub_colors)
# Out:
# ['blue', 'indigo', 'violet']

# %% [markdown]
# ### 4) Using Python List slice to get every nth-element from a list

# %%
# uses the step to return a sublist that includes every 2nd element of the color list

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
sub_colors = colors[::2]

print(sub_colors)
# Out:
# ['red', 'yellow', 'blue', 'violet']

# %% [markdown]
# ### 5) Using Python List slice to reverse a list

# %%
# last element to first element (reverse)

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
reversed_colors = colors[::-1]

print(reversed_colors)
# Out:
# ['violet', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red']

# %% [markdown]
# ### 6) Using Python List slice to substitute part a list
#
# ![image.png](data:image/png;base64,...)

# %%
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
colors[0:2] = ['black', 'white']

print(colors)
# Out:
# ['black', 'white', 'yellow', 'green', 'blue', 'indigo', 'violet']

# %% [markdown]
# ### 7) Using python List slice to partially replace and resize a list
#
# ![image.png](data:image/png;base64,...)

# %%
colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
print(f"The list has {len(colors)} elements")

colors[0:2] = ['black', 'white', 'gray']
print(colors)

print(f"\nThe list has {len(colors)} elements")
# Out:
# The list has 7 elements
# ['black', 'white', 'gray', 'yellow', 'green', 'blue', 'indigo', 'violet']
#
# The list has 8 elements

# %% [markdown]
# ### 8) Using Python list slice to delete elements

# %%
'''
The following shows how to use the list slice 
to delete the 3rd, 4th, and 5th elements from the colors list:
'''

colors = ['red', 'orange', 'yellow', 'green', 'blue', 'indigo', 'violet']
del colors[2:5]

print(colors)
# Out:
# ['red', 'orange', 'indigo', 'violet']

# %% [markdown]
# ## Summary
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # How to Unpack a List in Python

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Unpacking and packing
#
# ![image.png](data:image/png;base64,...)

# %%
colors = ['red', 'blue', 'green']
red, blue, *other = colors

print(red)
print(blue)
print(other)
# Out:
# red
# blue
# ['green']

# %%
# another example

colors = ['cyan', 'magenta', 'yellow', 'black']
cyan, magenta, *other = colors

print(cyan)
print(magenta)
print(other)
# Out:
# cyan
# magenta
# ['yellow', 'black']

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # How to Use a For Loop to Iterate over a List
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Using Python for loop to iterate over a list
#
# ![image.png](data:image/png;base64,...)

# %%
'''
In this example, the for loop assigns an individual element of the cities list 
to the city variable and prints out the city in each iteration.
'''

cities = ['New York', 'Beijing', 'Cairo', 'Mumbai', 'Mexico']

for city in cities:
  print(city)
# Out:
# New York
# Beijing
# Cairo
# Mumbai
# Mexico

# %% [markdown]
# ## Using Python for loop to iterate over a list with index
#
# ![image.png](data:image/png;base64,...)

# %%
cities = ['New York', 'Beijing', 'Cairo', 'Mumbai', 'Mexico']

for item in enumerate(cities):
  print(item)
# Out:
# (0, 'New York')
# (1, 'Beijing')
# (2, 'Cairo')
# (3, 'Mumbai')
# (4, 'Mexico')

# %%
# To access the index, you can unpack the tuple within the for loop statement like this:

cities = ['New York', 'Beijing', 'Cairo', 'Mumbai', 'Mexico']

for index, city in enumerate(cities, 1):
  print(f"{index}: {city}")
# Out:
# 1: New York
# 2: Beijing
# 3: Cairo
# 4: Mumbai
# 5: Mexico

# %%
help(enumerate)
# Out:
# Help on class enumerate in module builtins:
#
# class enumerate(object)
#  |  enumerate(iterable, start=0)
#  |
#  |  Return an enumerate object.
#  |
#  |    iterable
#  |      an object supporting iteration
#  |
#  |  The enumerate object yields pairs containing a count (from start, which
#  |  defaults to zero) and a value yielded by the iterable argument.
#  |
#  |  enumerate is useful for obtaining an indexed list:
#  |      (0, seq[0]), (1, seq[1]), (2, seq[2]), ...
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
# ...

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # How to Find the Index of an Element in a List
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
cities = ['New York', 'Beijing', 'Cairo', 'Mumbai', 'Mexico']
city = 'Osaka'

if city in cities:
  result = cities.index(city)
  print(f"The{city} has an index of {result}")
else:
  print(f"{city} doesn't exist in that list.")
# Out:
# Osaka doesn't exist in that list.

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Iterables

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)

# %%
# In fact, the range() function is an iterable because you can iterate over its result:

for index in range(3):
  print(index)
# Out:
# 0
# 1
# 2

# %%
# Also, a string is an iterable because you can use a for loop to iterate over it:

str = 'Iterables'
for ch in str:
  print(ch)
# Out:
# I
# t
# e
# r
# a
# b
# l
# e
# s

# %%
# Lists and tuples are also iterables because you can loop over them. For example:

ranks = ['high', 'medium', 'low']

for rank in ranks:
  print(rank)
# Out:
# high
# medium
# low

# %% [markdown]
# ## What is an operator
#
# ![image.png](data:image/png;base64,...)

# %%
colors = ['red', 'green', 'blue']
colors_iter = iter(colors)

color = next(colors_iter)
print(color)
# Out:
# red

# %%
colors = ['red', 'green', 'blue']
colors_iter = iter(colors)

color = next(colors_iter)
print(color)

color = next(colors_iter)
print(color)

color = next(colors_iter)
print(color)
# Out:
# red
# green
# blue

# %%
# If there isn’t any more element and you call the next() function, you’ll get an exception.

colors = ['red', 'green', 'blue']
colors_iter = iter(colors)

color = next(colors_iter)
print(color)

color = next(colors_iter)
print(color)

color = next(colors_iter)
print(color)

# cause an excpetion
# color = next(colors_iter)
# print(color)
# Out:
# red
# green
# blue

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
colors = ['red', 'green', 'blue']
iterator = iter(colors)

for color in iterator:
  print(color)
# Out:
# red
# green
# blue

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Transform List Elements with Python map() Function

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
help(map)
# Out:
# Help on class map in module builtins:
#
# class map(object)
#  |  map(func, *iterables) --> map object
#  |
#  |  Make an iterator that computes the function using arguments from
#  |  each of the iterables.  Stops when the shortest iterable is exhausted.
#  |
#  |  Methods defined here:
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __next__(self, /)
#  |      Implement next(self).
#  |
#  |  __reduce__(...)
#  |      Return state information for pickling.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.

# %%
def double(bonus):
  return bonus * 2

bonuses = [100, 200, 300]

iterator = map(double, bonuses)

print(iterator)
print(list(iterator))
# Out:
# ...
# [200, 400, 600]

# %%
# Or you make this code more concise by using a lambda expression like this:

bonuses = [100, 200, 300]
iterator = map(lambda bonus:bonus*2, bonuses)

print(iterator)
print(list(iterator))
# Out:
# ...
# [200, 400, 600]

# %% [markdown]
# ## More example map() function for lists

# %% [markdown]
# ### 1) Using the Python map() function for a list of strings

# %%
# capitalize first alphabet

names = ['ramadhan', 'ridho', 'arrohman']
new_names = map(lambda nama: nama.capitalize(), names)

print(new_names)
print(list(new_names))
# Out:
# ...
# ['Ramadhan', 'Ridho', 'Arrohman']

# %% [markdown]
# ### 2) Using the Python map() function to a list of tuples
#
# ![image.png](data:image/png;base64,...)

# %%
'''
In order to do so, you can use the map() function to create a new element of the list 
and add the new tax amount to each like this:
'''

carts = [['SmartPhone', 400],
         ['Tablet', 450],
         ['Laptop', 700]]

TAX = 0.1
carts = map(lambda item: [item[0], item[1], item[1]* TAX], carts)

print(list(carts))
# Out:
# [['SmartPhone', 400, 40.0], ['Tablet', 450, 45.0], ['Laptop', 700, 70.0]]

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)
