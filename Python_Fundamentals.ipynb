# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanridho16/Python_Docs/blob/main/Python_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Syntax

# %% [markdown]
# ## 1. Whitespace and indentation

# %%
# Python uses whitespace and identation to construct the code structure.

# define main function to print out something
def main():
  i = 1
  max = 10
  while(i< max):
    print(i)
    i = i+1

# %%
# call function main
main()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %% [markdown]
# ## 2. Comments

# %%
# This is a single line comment in Python

# %% [markdown]
# ## 3. Continuation of Statements

# %%
# if (a == True) and (b == False) and \
# (c == True):
# print("Continuation of statements")

# This technique can't use in python notebook I think.

# %% [markdown]
# ## 4. Identifiers

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Keywords

# %%
# Some words have special meanings in Python. They are called keywords

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Python is a evolving language. Python provides a special module for listing keyword

import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## 6. String Literals

# %%
# Python uses single quotes ('), double quotes ("), triple single quotes (''') and triple-double quotes (""") to denote a string literal.

s = 'This is a string'
print(s)
# Out:
# This is a string

# %%
s = "Another string using double quotes"
print(s)
# Out:
# Another string using double quotes

# %%
s = '''
  string can span multiple
  line
'''
print(s)
# Out:
#   string can span multiple
#   line

# %% [markdown]
# # Python Variables

# %% [markdown]
# ## 1. Creating variables
# variable_name = value

# %%
# example of variable
counter = 1

# %% [markdown]
# ## 2. Naming Variables
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Summary
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python String

# %% [markdown]
# ## 1. Introduction to Python String

# %%
message = 'This is a string in Python'
message = "This is also a string"

# If a string contains single quote, you should place it in double-quotes like this.
message = "It's a string"
print(message)
# Out:
# It's a string

# %%
# When a string contains double quotes, you can use the single quotes

message = '"Beautiful is better than ugly.". Said Tim Peters'
print(message)
# Out:
# "Beautiful is better than ugly.". Said Tim Peters

# %%
# The python interpreter will treat backslash character special. If you don't want to do it, u can se raw strings by addin letter 'r'

message = r'C:\python\bin'
print(message)
# Out:
# C:\python\bin

# %% [markdown]
# ## 2. Creating multiline strings

# %%
help_message = '''
Usage: mysql command
  -h hostname
  -d database name
  -u username
  -p password
'''
print(help_message)
# Out:
# Usage: mysql command
#   -h hostname
#   -d database name
#   -u username
#   -p password

# %% [markdown]
# ## 3. Using Variables in Python strings with the f-strings

# %%
name = 'John'
message = 'Hi'

# To do it, you place the letter f before the opening quotation mark and put the brace around the variable name:
name = 'Ramadhan'
message = f'Hi {name}'
print(message)
# Out:
# Hi Ramadhan

# %% [markdown]
# ## 4. Concatenation Python Strings

# %%
greeting = 'Good ' 'Morning!'
print(greeting)
# Out:
# Good Morning!

# %%
# concatenate two string variables, using operator '+'

greeting = 'Good'
time = 'Afternoon'

greeting = greeting + time + '!'
print(greeting)
# Out:
# GoodAfternoon!

# %% [markdown]
# ## 5. Accessing string elements

# %%
str = "Python String"
print(str[0]) # P
print(str[1]) # y
# Out:
# P
# y

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 6. Getting the length of a string

# %%
str = "Python String"
str_len = len(str)
print(str_len)    # whitespace is also included
# Out:
# 13

# %% [markdown]
# ## 7. Slicing strings

# %%
str = "Python String"
print(str[0:2])     # it will be stop before index 2
# Out:
# Py

# %%
# The Syntax
# string [start:end]
# Python string are immutable

str = "Python String"
str[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-cb0bd541c960> in <module>()
#       4
#       5 str = "Python String"
# ----> 6 str[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
# When want to modify string, must create a new one from existing string

str = "Python String"
new_str = 'J' + str[1:]
print(new_str)
# Out:
# Jython String

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Numbers

# %% [markdown]
# ## 1. Underscores in numbers

# %%
# count 10000000000

# to make long numbers more readable, you can group digits using underscores.
count = 10_000_000_000
print(count)
# Out:
# 10000000000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Boolean

# %%
is_active = True
is_admin = False

# %%
# When compare two numbers, python return a boolean value
20 > 10
20 < 10
# Out:
# False

# %%
20 > 10
# Out:
# True

# %% [markdown]
# ## The bool() function

# %%
bool('Hi')
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(100)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# ## Falsy and Truthy values

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Constant
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Python Comments

# %% [markdown]
# ## Python Docstring
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### One-line docstring
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Multi-line docstring
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)
