# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanridho16/Python_Docs/blob/main/Loop_with_Else_Clause.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python for else
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Introduction
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python for else statement example
#
# ![image.png](data:image/png;base64,...)

# %%
people = [{'name' : 'John', 'age' : 25},
          {'name' : 'Jane', 'age' : 22},
          {'name' : 'Peter', 'age' : 30},
          {'name' : 'Jennifer', 'age' : 28}]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = input('Enter a name: ').capitalize()

found = False
for person in people:
  if person['name'] == name:
    found = True
    print(person)
    break

if not found:
  print(f"{name} not found")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f9d9b6dcff76> in <module>
# ----> 1 name = input('Enter a name: ').capitalize()
#       2
#       3 found = False
#       4 for person in people:
#       5   if person['name'] == name:
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### Example using for else (from above problem)

# %%
name = input('Enter a name on the list: ').capitalize()

for person in people:
  if person['name'] == name:
    print(person)
    break

else:
  print(f"{name} not found")
# Out:
# Enter a name on the list: ridho
# Ridho not found

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Summary
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # While Else Statement
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Introduction
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python while else statement
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Manual Way

# %%
basket = [
    {'fruit': 'apple', 'qty': 20},
    {'fruit': 'banana', 'qty': 30},
    {'fruit': 'orange', 'qty': 10}
]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fruit = input('Enter a fruit:')

index = 0
found_it = False

while index < len(basket):
  item = basket[index]
  # check the fruit name
  if item['fruit'] == fruit:
    found_it = True
    print(f"The basket has {item['qty']} {item['fruit']}(s)")
    break

  index += 1

if not found_it:
  qty = int(input(f"Enter the qty for {fruit}"))
  basket.append({'fruit': fruit, 'qty': qty})
  print(basket)
# Out:
# Enter a fruit:bana
# Enter the qty for bana20
# [{'fruit': 'apple', 'qty': 20}, {'fruit': 'banana', 'qty': 30}, {'fruit': 'orange', 'qty': 10}, {'fruit': 'bana', 'qty': 20}]

# %%
print(basket)
# Out:
# [{'fruit': 'apple', 'qty': 20}, {'fruit': 'banana', 'qty': 30}, {'fruit': 'orange', 'qty': 10}, {'fruit': 'bana', 'qty': 20}]

# %%
len(basket)
# Out:
# 3

# %% [markdown]
# ### Faster Way

# %%
fruit = input('Enter a fruit:')

index = 0

while index < len(basket):
  item = basket[index]
  # check the fruit name
  if item['fruit'] == fruit:
    print(f"The basket has {item['qty']} {item['fruit']}(s)")
    found_it = True
    break

  index += 1

else:
  qty = int(input(f'Enter the qty for {fruit}'))
  basket.append({'fruit': fruit, 'qty': qty})
  print(basket)
# Out:
# Enter a fruit:grape
# Enter the qty for grape30
# [{'fruit': 'apple', 'qty': 20}, {'fruit': 'banana', 'qty': 30}, {'fruit': 'orange', 'qty': 10}, {'fruit': 'bana', 'qty': 20}, {'fruit': 'grape', 'qty': 30}]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # do...while Loop Statement Emulation
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Python do...while loop emulation example
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Theoritical Way

# %%
from random import randint

# determinate the range
MIN = 0
MAX = 10

# generate a scret number
secret_number = randint(MIN, MAX)

# initialize the attempt
attempt = 0

# The first attempt
input_number = int(input(f"Enter a number between {MIN} and {MAX}: "))
attempt += 1

if input_number > secret_number:
  print('It should be smaller.')
elif input_number < secret_number:
  print('It should be bigger.')
else:
  print(f"Bingo! {attempt} attempt(s)")


# From the second attempt
while input_number != secret_number:
  input_number = int(input(f"Enter a number between {MIN} and {MAX}: "))
  attempt += 1

  if input_number > secret_number:
    print('It should be smaller.')
  elif input_number < secret_number:
    print('It should be bigger.')
  else:
    print(f"Bingo! {attempt} attempt(s)")
# Out:
# Enter a number between 0 and 10: 9
# It should be smaller.
# Enter a number between 0 and 10: 8
# It should be smaller.
# Enter a number between 0 and 10: 5
# It should be smaller.
# Enter a number between 0 and 10: 3
# Bingo! 4 attempt(s)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Faster way to avoid duplicate code

# %%
from random import randint

# determine the range
MIN = 0
MAX = 10

# generate a secret number
secret_number = randint(MIN, MAX)

# initialize the attempt
attempt = 0

while True:
  attempt += 1

  input_number = int(input(f"Enter a number between {MIN} and {MAX} :"))

  if input_number > secret_number:
    print("It should be smaller.")
  elif input_number < secret_number:
    print("It should be bigger")
  else:
    print(f"Bingo! {attempt} attempt(s)")
    break
# Out:
# Enter a number between 0 and 10:0
# It should be bigger
# Enter a number between 0 and 10:5
# It should be smaller.
# Enter a number between 0 and 10:3
# It should be smaller.
# Enter a number between 0 and 10:2
# Bingo! 4 attempt(s)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)
