# %% [markdown]
# <a href="https://colab.research.google.com/github/ramadhanridho16/Python_Docs/blob/main/More_On_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Unpacking Tuple

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numbers = 10, 20, 30
print(type(numbers))
# Out:
# <class 'tuple'>

# %% [markdown]
# ## Using Unpacking tuple to swap values of two variables

# %% [markdown]
# ### Using Logic Way

# %%
# Tuple is mutable but it can be swapped

x = 10
y = 20

print(f"x = {x}, y = {y}")

tmp = x
x = y
y = tmp

print(f"x = {x}, y = {y}")
# Out:
# x = 10, y = 20
# x = 20, y = 10

# %% [markdown]
# ### Using unpacking tuple way

# %%
x = 10
y = 20

print(f"x={x}, y={y}")

x, y = y, x

print(f"x={x}, y={y}")
# Out:
# x=10, y=20
# x=20, y=10

# %% [markdown]
# ## ValueError: too many values to unpack
#
# ![image.png](data:image/png;base64,...)

# %%
x, y, _, _= 10, 20, 30, 40

# %% [markdown]
# ## Extended Unpacking using the *operator
#
# ![image.png](data:image/png;base64,...)

# %%
a, b, *other = 10, 20, 30, 40, 50

# %%
print(other)
# Out:
# [30, 40, 50]

# %% [markdown]
# ## Using the * operator on the right hand side

# %%
odd_numbers = (1, 3, 5)
even_numbers = (2, 4, 6)

# merge into a single tuple
numbers = (*odd_numbers, *even_numbers)
print(numbers)
# Out:
# (1, 3, 5, 2, 4, 6)

# %% [markdown]
# ## Summary
#
# ![image.png](data:image/png;base64,...)
